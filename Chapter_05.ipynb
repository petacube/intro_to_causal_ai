# %%
from itertools import combinations

import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import graphviz

# %%
COLORS = [
    '#00B0F0',
    '#FF0000',
    '#B0F000'
]

# %% [markdown]
# # Chapter 05
#
# This chapter introduces the concept of mapping between distributions and graphs. We define and demonstrate basic graphical structures and (briefly) talk about statistical and graphical independence. Finally, we implement regression models to show how different graphical structures manifest themselves in statistical (in)dependencies.

# %% [markdown]
# ## Visualizations

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,2.75!', '2,3!', '0,1!']

edges = ['AB', 'CB', 'CA']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_markov_01')

graph

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,2.75!', '2,3!', '0,1!']

edges = ['AB', 'CB', 'AC']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_markov_02')

graph

# %% [markdown]
# ## Causal graphs and independence

# %%
NOISE_LEVEL = .2
N_SAMPLES = 1000

# %% [markdown]
# ### A chain: `A -> B -> C`

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,0!', '1.5,0!', '3,0!']

edges = ['AB', 'BC']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_chain_00')

graph

# %%
# Generate the data
a = np.random.randn(N_SAMPLES) 
b = a + NOISE_LEVEL*np.random.randn(N_SAMPLES) 
c = b + NOISE_LEVEL*np.random.randn(N_SAMPLES) 

# Get combinations
combs = list(combinations([('a', a), ('b', b), ('c', c)], 2))

# %%
# Plot
plt.figure(figsize=(12, 8))

for i, comb in enumerate(combs):
    key_1, key_2 = comb[0][0], comb[1][0]
    
    
    plt.subplot(2, 2, i + 1)
    plt.scatter(comb[0][1], comb[1][1], alpha=.5, color=COLORS[0])
    plt.xlabel(key_1)
    plt.ylabel(key_2)

plt.suptitle('Chain - scatterplots')
plt.show()

# %%
X = pd.DataFrame(np.vstack([a, b]).T, columns=['A', 'B'])
X = sm.add_constant(X, prepend=True)

model = sm.OLS(c, X)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                 1.253e+04
# Date:                Sat, 30 Sep 2023   Prob (F-statistic):               0.00
# Time:                        11:27:10   Log-Likelihood:                 183.97
# No. Observations:                1000   AIC:                            -361.9
# Df Residuals:                     997   BIC:                            -347.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0039      0.006     -0.611      0.541      -0.016       0.009
# A              0.0098      0.035      0.284      0.777      -0.058       0.078
# B              0.9916      0.033     29.764      0.000       0.926       1.057
# ==============================================================================
# Omnibus:                        0.165   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.921   Jarque-Bera (JB):                0.206
# Skew:                           0.029   Prob(JB):                        0.902
# Kurtosis:                       2.961   Cond. No.                         10.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### A fork: `A <- B -> C`

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,0!', '1.5,0!', '3,0!']

edges = ['BA', 'BC']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_fork_00')

graph

# %%
# Generate the data
b = np.random.randn(N_SAMPLES) 
a = b + NOISE_LEVEL*np.random.randn(N_SAMPLES) 
c = b + NOISE_LEVEL*np.random.randn(N_SAMPLES) 

# Get combinations
combs = list(combinations([('a', a), ('b', b), ('c', c)], 2))

# %%
# Plot
plt.figure(figsize=(12, 8))

for i, comb in enumerate(combs):
    key_1, key_2 = comb[0][0], comb[1][0]
    
    
    plt.subplot(2, 2, i + 1)
    plt.scatter(comb[0][1], comb[1][1], alpha=.5, color=COLORS[0])
    plt.xlabel(key_1)
    plt.ylabel(key_2)

plt.suptitle('Fork - scatterplots')
plt.show()

# %%
X = pd.DataFrame(np.vstack([a, b]).T, columns=['A', 'B'])
X = sm.add_constant(X, prepend=True)

model = sm.OLS(c, X)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                 1.237e+04
# Date:                Sat, 30 Sep 2023   Prob (F-statistic):               0.00
# Time:                        11:27:11   Log-Likelihood:                 224.51
# No. Observations:                1000   AIC:                            -443.0
# Df Residuals:                     997   BIC:                            -428.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0072      0.006      1.169      0.243      -0.005       0.019
# A              0.0601      0.030      2.012      0.045       0.001       0.119
# B              0.9435      0.031     30.744      0.000       0.883       1.004
# ==============================================================================
# Omnibus:                        2.108   Durbin-Watson:                   2.119
# Prob(Omnibus):                  0.349   Jarque-Bera (JB):                2.054
# Skew:                          -0.062   Prob(JB):                        0.358
# Kurtosis:                       2.816   Cond. No.                         9.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### A collider: `A -> B <- C`

# %%
graph = graphviz.Digraph(format='png', engine='neato')

nodes = ['A', 'B', 'C']
positions = ['0,0!', '1.5,0!', '3,0!']

edges = ['AB', 'CB']

[graph.node(n, pos=pos) for n, pos in zip(nodes, positions)]
graph.edges(edges)

graph.render(f'img/ch_05_collider_00')

graph

# %%
# Generate the data
a = np.random.randn(N_SAMPLES) 
c = np.random.randn(N_SAMPLES) 
b = a + c + NOISE_LEVEL*np.random.randn(N_SAMPLES) 

# Get combinations
combs = list(combinations([('a', a), ('b', b), ('c', c)], 2))

# %%
# Plot
plt.figure(figsize=(12, 8))

for i, comb in enumerate(combs):
    key_1, key_2 = comb[0][0], comb[1][0]
    
    
    plt.subplot(2, 2, i + 1)
    plt.scatter(comb[0][1], comb[1][1], alpha=.5, color=COLORS[0])
    plt.xlabel(key_1)
    plt.ylabel(key_2)

plt.suptitle('Collider - scatterplots')
plt.show()

# %%
X = pd.DataFrame(np.vstack([a, b]).T, columns=['A', 'B'])
X = sm.add_constant(X, prepend=True)

model = sm.OLS(c, X)
results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                 1.187e+04
# Date:                Sat, 30 Sep 2023   Prob (F-statistic):               0.00
# Time:                        11:27:11   Log-Likelihood:                 221.41
# No. Observations:                1000   AIC:                            -436.8
# Df Residuals:                     997   BIC:                            -422.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.006     -0.116      0.907      -0.013       0.011
# A             -0.9622      0.008   -113.309      0.000      -0.979      -0.946
# B              0.9591      0.006    154.047      0.000       0.947       0.971
# ==============================================================================
# Omnibus:                        6.934   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                6.825
# Skew:                          -0.193   Prob(JB):                       0.0330
# Kurtosis:                       3.124   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
